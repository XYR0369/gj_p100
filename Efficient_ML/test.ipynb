# %%
def fun(a):
    a = a+1
    return a

b = 5
c = fun(b)
print(b)
print(c)
# Out:
# 5
# 6

# %%
def list_append(a:list):
    a.append(1)
    return a

b = [1,2,3]
c = list_append(b)
print(b,c)
# Out:
# [1, 2, 3, 1] [1, 2, 3, 1]

# %%
import torch
# a = torch.arange(5)
a = torch.tensor([1,0,2,3,1])
a == 1
b = torch.tensor([1,2,3,4,5])
b[a == 1]
# Out:
# tensor([1, 5])

# %%
a = torch.arange(6)*2
a
b = torch.arange(6)+1
c = a/b
print(a,b,c)
# Out:
# tensor([ 0,  2,  4,  6,  8, 10]) tensor([1, 2, 3, 4, 5, 6]) tensor([0.0000, 1.0000, 1.3333, 1.5000, 1.6000, 1.6667])

# %%
import torch
a = torch.tensor([[[1,2,3,4],[4,5,6,7],[7,8,9,10]],[[2,2,3,4],[5,5,6,7],[8,8,9,10]]])
print(a)
print(a.sum(0))
print(a.sum(1))
print(a.sum(2))

b = torch.tensor([[1,2,3,4],[4,5,6,7],[7,8,9,10]])
print(b)
print(b.sum(0))
print(b.sum(1))

# sum(dim)  是将对应 dim 上的元素进行求和（想想维持其他的维度不变，沿着 dim 方向压扁坍缩），结果自动剔除掉求和的维度，整体降了一维
# Out:
# tensor([[[ 1,  2,  3,  4],
#          [ 4,  5,  6,  7],
#          [ 7,  8,  9, 10]],
#
#         [[ 2,  2,  3,  4],
#          [ 5,  5,  6,  7],
#          [ 8,  8,  9, 10]]])
# tensor([[ 3,  4,  6,  8],
#         [ 9, 10, 12, 14],
#         [15, 16, 18, 20]])
# tensor([[12, 15, 18, 21],
#         [15, 15, 18, 21]])
# tensor([[10, 22, 34],
#         [11, 23, 35]])
# tensor([[ 1,  2,  3,  4],
#         [ 4,  5,  6,  7],
#         [ 7,  8,  9, 10]])
# tensor([12, 15, 18, 21])
# tensor([10, 22, 34])

# %%
import torch

# 创建两个形状不同的张量
a = torch.tensor([1, 2, 3])
b = torch.tensor([[1], [2], [3]])

# 使用加法进行广播
c = a + b  # c 的形状将是 torch.Size([3, 3])

# 查看结果
print(c)
# Out:
# tensor([[2, 3, 4],
#         [3, 4, 5],
#         [4, 5, 6]])

# %%
# import torch
# import torch.nn.functional as F

# # 假设输入特征数为 4，输出特征数为 3
# input_features = 4
# output_features = 3

# # 创建输入数据，权重和偏置
# x = torch.randn(10, input_features)  # 假设有 10 个样本
# weight = torch.randn(output_features, input_features)
# bias = torch.randn(output_features)

# # 应用线性变换
# y1 = F.linear(x, weight, bias)
# # y2 = x*weight + bias
# # y3 = weight*x + bias
# print(x.size())
# print(weight.T.size())
# weight1 = weight.T
# y3 = x*(weight.T)+ bias

# %%
a = torch.tensor([[1,2,3],[1,2,3]])
b = torch.tensor([[1,2,3],[1,2,3]])
c = torch.tensor([[1,2,3],[1,2,3]])
print(a.size(0),a.size(1))
list = [a,b,c]
cat_samples = torch.cat(list, dim=1)
print(cat_samples.shape[0], cat_samples.shape[1])
# Out:
# 2 3
# 2 9

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 假设我们有以下二维张量
feature_map = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# 将张量转换为NumPy数组
tensor_np = np.array(feature_map)

# 创建一个新的图和子图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制从每个点到z=0位置的线段
for i in range(tensor_np.shape[0]):
    for j in range(tensor_np.shape[1]):
        # 绘制线段的起点和终点
        ax.plot([j, j], [i, i], [0, tensor_np[i, j]], 'b-')

# 设置坐标轴标签
ax.set_xlabel('Column Index')
ax.set_ylabel('Row Index')
ax.set_zlabel('Value')

# 设置坐标轴的范围
ax.set_xlim([0, tensor_np.shape[1]])
ax.set_ylim([0, tensor_np.shape[0]])
ax.set_zlim([0, np.max(tensor_np)])

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 假设我们有以下二维张量
# feature_map = [
#     [1, 2, 3],
#     [4, 5, 6],
#     [7, 8, 9]
# ]

# feature_map = result[0:20,:]
# tensor_np = np.array(feature_map)

# 模拟数据
tensor_np = np.random.rand(10, 10) * 2000  # 生成一个10x10的随机张量，值在0到2000之间

# 创建一个新的图和子图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制每个元素
for i in range(tensor_np.shape[0]):
    for j in range(tensor_np.shape[1]):
        # 根据值的不同，设置不同的颜色和透明度
        if tensor_np[i, j] < 1000:
            color = 'b'  # 蓝色
        else:
            color = 'r'  # 红色
        ax.plot([j, j], [i, i], [0, tensor_np[i, j]], color + '-', alpha=0.7, linewidth=0.3)

# 设置坐标轴标签
ax.set_xlabel('Input feature')
ax.set_ylabel('Linear layers')
ax.set_zlabel('Value')

# 设置坐标轴的范围
ax.set_xlim([0, tensor_np.shape[1] - 1])
ax.set_ylim([0, tensor_np.shape[0] - 1])
ax.set_zlim([0, np.max(tensor_np)])

# 显示图形
plt.show()

# %%
import torch

# 创建一个包含数值的张量
values = torch.tensor([[5, 10, 1, 8, 7, 3, 6],[20, 10, 1, 8, 7, 3, 6]])

# 使用torch.topk找出最大的3个元素及其索引
top_values, top_indices = torch.topk(values, 2, dim = 1)

# 打印结果
print("Top 3 values:", top_values)
print("Indices of top 3 values:", top_indices)
# Out:
# Top 3 values: tensor([[10,  8],
#         [20, 10]])
# Indices of top 3 values: tensor([[1, 3],
#         [0, 1]])

# %%
tensor_int = torch.randint(0, 10, (10,))

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

data = load_iris()
X = data['data']
y = data['target']
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True)

class IrisModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden = nn.Linear(4, 8)
        self.act = nn.ReLU()
        self.output = nn.Linear(8, 3)

    def forward(self, x):
        x = self.act(self.hidden(x))
        x = self.output(x)
        return x

# loss metric and optimizer
model = IrisModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# prepare model and training parameters
n_epochs = 100
batch_size = 10
batch_start = torch.arange(0, len(X_train), batch_size)

# training loop
for epoch in range(n_epochs):
    for start in batch_start:
        # take a batch
        X_batch = X_train[start:start+batch_size]
        y_batch = y_train[start:start+batch_size]
        # forward pass
        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)
        # backward pass
        optimizer.zero_grad()
        loss.backward()
        # update weights
        optimizer.step()

# validating model
y_pred = model(X_test)
acc = (torch.argmax(y_pred, 1) == y_test).float().mean()
acc = float(acc)*100
print("Model accuracy: %.2f%%" % acc)
# Out:
# Model accuracy: 100.00%

# %%
import torch.onnx
torch.onnx.export(model, X_test, 'iris.onnx', input_names=["features"], output_names=["logits"])

# %%
# import torchvision

# from nnviz import drawing, inspection

# # User code, for the sake of this example we'll use a torchvision model
# my_model = torchvision.models.resnet18()

# # Create an inspector: an object that will inspect the model and create a graph
# inspector = inspection.TorchFxInspector()

# # Inspect the model and draw the graph
# graph = inspector.inspect(my_model)

# # Create a drawer: an object that will draw the graph to a file
# drawer = drawing.GraphvizDrawer("my_model.pdf")

# # Draw the graph
# drawer.draw(graph)

# %%
# inp = torch.tensor([[1,2,3],[2,3,4]])
inp = [torch.tensor([1,2,3]),torch.tensor([1,2,3])]
lista = [x for x in inp]
listb = [x.unsqueeze(0) for x in inp]
inp = torch.cat([x.unsqueeze(0) for x in inp], dim=0).unsqueeze(0)
# print(inp)
print(lista)
print(listb)

print(torch.cat(listb))
print(inp)
# Out:
# [tensor([1, 2, 3]), tensor([1, 2, 3])]
# [tensor([[1, 2, 3]]), tensor([[1, 2, 3]])]
# tensor([[1, 2, 3],
#         [1, 2, 3]])
# tensor([[[1, 2, 3],
#          [1, 2, 3]]])
